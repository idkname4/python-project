# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

# %%
df=pd.read_excel(r'C:\Users\HP\Downloads\ice.xlsx')
df=df.set_index('Date')

# %%
df
# Out:
#             Flavor Rating  Texture Rating  Overall Rating
# Date
# 2022-01-01              0               2               2
# 2022-01-02             10               5              15
# 2022-01-03              1               5               6
# 2022-01-04              5               4               9
# 2022-01-05              5               0               5
# 2022-01-06              3               2               5
# 2022-01-07              1               7               8

# %%
print(plot.style.available)  #this will show alll the styles
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plot.style.use('fivethirtyeight') #this will apply particular style to all

# %%
df.plot(kind='line')
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind='line',subplots=True)1
# Out:
#   Cell In[105], line 1
#     df.plot(kind='line',subplots=True)1
#                                       ^
# SyntaxError: invalid syntax

# %%
df.plot(kind='line',title="Ice Cream Rating",xlabel='Dates',ylabel='Ratings')
# Out:
# <Axes: title={'center': 'Ice Cream Rating'}, xlabel='Dates', ylabel='Ratings'>

# %%
df.plot(kind='bar',title="Ice Cream Rating",xlabel='Dates',ylabel='Ratings')
# Out:
# <Axes: title={'center': 'Ice Cream Rating'}, xlabel='Dates', ylabel='Ratings'>

# %%
df.plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Date'>

# %%
df['Overall Rating'].plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.barh(stacked=True) # df.plot.barh()
# Out:
# <Axes: ylabel='Date'>

# %%
df.plot.scatter(x='Texture Rating',y="Overall Rating") #need to specify the x and y
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df.plot.scatter(x='Texture Rating',y="Overall Rating",s=500,c=['yellow','red','green','pink','red','green','pink']) #need to specify the x and y
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df.plot.hist(bins=20) #histagrams are good for shoiwng distributions of variables of logical nos but we have random nos
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot()#so we have in flavor rating *1st candestick it represents max ,then 75%, 50%,25%,min)from top to bottom :D
# Out:
# <Axes: >

# %%
df.plot.area()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.area(figsize=(10,8))
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.pie(y='Flavor Rating',figsize=(5,5))
# Out:
# <Axes: ylabel='Flavor Rating'>
